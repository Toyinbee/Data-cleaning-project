# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Toyin\OneDrive\Desktop\excel works i have done\movies data for ds assignment.csv")
df
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
df.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
# 5   ts22164         Monty Python's Flying Circus   SHOW
# 6   tm70993                        Life of Brian  MOVIE
# 7   tm14873                          Dirty Harry  MOVIE
# 8  tm119281                     Bonnie and Clyde  MOVIE
# 9   tm98978                      The Blue Lagoon  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# ...

# %%
df.tail(10)
# Out:
#              id                                      title   type  \
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5841   tm985215                       Princess 'Daya'Reese  MOVIE
# 5842  tm1066324          Super Monsters: Once Upon a Rhyme  MOVIE
# 5843  tm1097142                                   My Bride  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 5840  In 14th-century Mali, an ambitious young royal...          2022
# 5841  Reese is a con artist from Manila who dreams o...          2021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# ...

# %%
df.shape
# Out:
# (5850, 15)

# %%
df.size
# Out:
# 87750

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5850.000000  5850.000000  2106.000000  5368.000000  5.352000e+03
# mean    2016.417094    76.888889     2.162868     6.510861  2.343938e+04
# std        6.937726    39.002509     2.689041     1.163826  9.582047e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2016.000000    44.000000     1.000000     5.800000  5.167500e+02
# 50%     2018.000000    83.000000     1.000000     6.600000  2.233500e+03
# 75%     2020.000000   104.000000     2.000000     7.300000  9.494000e+03
# max     2022.000000   240.000000    42.000000     9.600000  2.294231e+06
#
#        tmdb_popularity   tmdb_score
# count      5759.000000  5539.000000
# mean         22.637925     6.829175
# std          81.680263     1.170391
# min           0.009442     0.500000
# 25%           2.728500     6.100000
# 50%           6.821000     6.900000
# 75%          16.590000     7.537500
# ...

# %%
df.sample()
# Out:
#           id    title   type  \
# 333  tm78671  Cleaner  MOVIE
#
#                                            description  release_year  \
# 333  Single father and former cop Tom Cutler has an...          2007
#
#     age_certification  runtime                 genres production_countries  \
# 333                 R       88  ['thriller', 'crime']               ['US']
#
#      seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 333      NaN  tt0896798         6.1     42285.0           11.509         6.0

# %%
df.isnull( ).sum( )
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %%
df.nunique()
# Out:
# id                      5850
# title                   5798
# type                       2
# description             5829
# release_year              63
# age_certification         11
# runtime                  202
# genres                  1726
# production_countries     452
# seasons                   26
# imdb_id                 5447
# imdb_score                80
# imdb_votes              3880
# tmdb_popularity         4889
# tmdb_score               394
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5850, step=1)

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
df.memory_usage()
# Out:
# Index                     128
# id                      46800
# title                   46800
# type                    46800
# description             46800
# release_year            46800
# age_certification       46800
# runtime                 46800
# genres                  46800
# production_countries    46800
# seasons                 46800
# imdb_id                 46800
# imdb_score              46800
# imdb_votes              46800
# tmdb_popularity         46800
# tmdb_score              46800
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (1667, 15)

# %%
df.nlargest(10,'release_year')
# Out:
#             id                      title  type  \
# 4693  ts252861              Resident Evil  SHOW
# 4700  ts271450         The Lincoln Lawyer  SHOW
# 4701  ts277084                Man vs. Bee  SHOW
# 4704  ts356995    How to Change Your Mind  SHOW
# 4705  ts269395       God's Favorite Idiot  SHOW
# 4706  ts353844  Keep Sweet: Pray and Obey  SHOW
# 4710  ts306335                 Boo, Bitch  SHOW
# 4713  ts108385             Inventing Anna  SHOW
# 4715  ts308317         Snowflake Mountain  SHOW
# 4717  ts264270       Anatomy of a Scandal  SHOW
#
#                                             description  release_year  \
# 4693  Nearly three decades after the discovery of th...          2022
# 4700  Sidelined after an accident, hotshot Los Angel...          2022
# 4701  A man finds himself at war with a bee while ho...          2022
# 4704  Author Michael Pollan leads the way in this do...          2022
# 4705  Clark Thompson, a midlevel tech-support employ...          2022
# ...

# %%
df.isna()
# Out:
#          id  title   type  description  release_year  age_certification  \
# 5     False  False  False        False         False              False
# 26    False  False  False        False         False              False
# 35    False  False  False        False         False              False
# 44    False  False  False        False         False              False
# 45    False  False  False        False         False              False
# ...     ...    ...    ...          ...           ...                ...
# 5784  False  False  False        False         False              False
# 5785  False  False  False        False         False              False
# 5801  False  False  False        False         False              False
# 5819  False  False  False        False         False              False
# 5831  False  False  False        False         False              False
#
#       runtime  genres  production_countries  seasons  imdb_id  imdb_score  \
# ...

# %%
df.isna().head()
# Out:
#        id  title   type  description  release_year  age_certification  \
# 5   False  False  False        False         False              False
# 26  False  False  False        False         False              False
# 35  False  False  False        False         False              False
# 44  False  False  False        False         False              False
# 45  False  False  False        False         False              False
#
#     runtime  genres  production_countries  seasons  imdb_id  imdb_score  \
# 5     False   False                 False    False    False       False
# 26    False   False                 False    False    False       False
# 35    False   False                 False    False    False       False
# 44    False   False                 False    False    False       False
# 45    False   False                 False    False    False       False
#
#     imdb_votes  tmdb_popularity  tmdb_score
# 5        False            False       False
# ...

# %%
df.duplicated()
# Out:
# 5       False
# 26      False
# 35      False
# 44      False
# 45      False
#         ...
# 5784    False
# 5785    False
# 5801    False
# 5819    False
# 5831    False
# Length: 1667, dtype: bool

# %%
df['type'].value_counts()
# Out:
# SHOW    1667
# Name: type, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                  release_year   runtime   seasons  imdb_score  imdb_votes  \
# release_year         1.000000  0.148395 -0.560456   -0.195005   -0.160576
# runtime              0.148395  1.000000 -0.134481    0.234882    0.085257
# seasons             -0.560456 -0.134481  1.000000    0.116403    0.201393
# imdb_score          -0.195005  0.234882  0.116403    1.000000    0.257452
# imdb_votes          -0.160576  0.085257  0.201393    0.257452    1.000000
# tmdb_popularity     -0.052432  0.074019  0.164014    0.087494    0.520398
# tmdb_score          -0.049391  0.000562  0.062248    0.342632    0.126829
#
#                  tmdb_popularity  tmdb_score
# release_year           -0.052432   -0.049391
# runtime                 0.074019    0.000562
# seasons                 0.164014    0.062248
# imdb_score              0.087494    0.342632
# imdb_votes              0.520398    0.126829
# tmdb_popularity         1.000000    0.103529
# tmdb_score              0.103529    1.000000

# %%
df.shape
# Out:
# (1667, 15)

# %%
df.to_csv(r"C:\Users\Toyin\OneDrive\desktop\ my cleaned.csv")
